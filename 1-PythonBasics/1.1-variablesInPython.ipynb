# %%
a = 100

# %% [markdown]
# Declaring and assigning variables

# %%
age = 32
height = 7.1
name = 'Kelly'
isStudent = True

print(age)
print(height)
print(name)
print(isStudent)
# Out:
# 32
# 7.1
# Kelly
# True

# %% [markdown]
# # Naming Conventions
# 1. variable names should be descriptive
# 2. they must start with a letter / '_'
# 3. variable names are case sensitive

# %%
_Name = 'Jerry'
Name = 'kIeron'
name = 'Lim'
print(_Name)
print(Name)
print(name)
# Out:
# Jerry
# kIeron
# Lim

# %% [markdown]
# 3. Case Sensitivity

# %% [markdown]
# 4. Python is Dynamically typed - type of a variable is determined at runtime

# %% [markdown]
# 5. Type Conversion

# %%
age = 25
print(type(age))

age_str = str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 25
# <class 'str'>

# %% [markdown]
# ### Dynamic Typing
# Python allows the type of variable to change as the program  executes

# %%
var = 10
print(var , type (var))

var = 'new string'
print(var , type (var))
# Out:
# 10 <class 'int'>
# new string <class 'str'>

# %%
age = int(input('what is your age?'))
print(age, type(age))
# Out:
# 76 <class 'int'>

# %% [markdown]
# Basic Calculator

# %%
num1 = float(input('Enter the first number'))
num2 = float(input('Enter the second number'))

sum = num1 + num2
difference = num1 - num2
product = num1 * num2
quotient = num1 / num2

print('sum = ', sum)
print('difference =', difference)
print('product = ', product)
print('quotient = ', quotient)
# Out:
# sum =  54.0
# difference = 36.0
# product =  405.0
# quotient =  5.0

# %% [markdown]
# ## Datatypes in python
#
# 1. Definition - Datatypes are a classification of data which tell the compiler or interpreter how the programmer intends to use the data. They determine the type of operations to be performed
# 2. Importance - they ensures that data is stored in an efficient way.

# %%
## Integer example
age = 35
type(age)
# Out:
# int

# %%
## floating point datatype
height = 5.09
type(height)
# Out:
# float

# %%
## string datatype example
name = 'Kelly'
type(name)
# Out:
# str

# %%
## boolean dataType


isTrue = True
type(isTrue)
# Out:
# bool

# %%
a = 10
b = 10
type(a == b)
# Out:
# bool

# %%
## common errors in datatypes

result = "Hello" + 76
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 ## common errors in datatypes
# ----> 3 result = "Hello" + 76
#
# TypeError: can only concatenate str (not "int") to str

# %%
result = 'Hello' + str(76)
print(result)
# Out:
# Hello76

# %% [markdown]
# ## Operators in Python

# %%
## Arithmetic Operations
a = 10
b = 15
addResult = a + b
subResult = a - b
mulResult = a * b
divResult = a / b
floorDivisionResult = a // b
modulusResult = a % b
exponentResult = a ** b
print(addResult)
print(subResult)
print(mulResult)
print(divResult)
print(floorDivisionResult)
print(modulusResult)
print(exponentResult)
# Out:
# 25
# -5
# 150
# 0.6666666666666666
# 0
# 10
# 1000000000000000

# %%
## Comparison Operators

a = 10
b = 90
a == b
# Out:
# False

# %%
str1 = 'Glam'
str2 = 'Glam'
str1 == str2
# Out:
# True

# %%
str1 != str2
# Out:
# False

# %%
str3 = 'gleam'
str4 = 'Gleam'
str3!= str4
# Out:
# True

# %%
num1 = 90
num2 = 65

num1 < num2
# Out:
# False

# %%
n1 = 45
n2 = 45

n1 >= n2
# Out:
# True

# %%
## Logical Operators - And, Not, OR
h1 = True
h2 = True
result = h1 and h2
print(result)
# Out:
# True

# %%
h3 = False
h4 = False
result = h3 or h4
print(result)
# Out:
# False

# %%
h5 = True
not h5
# Out:
# False

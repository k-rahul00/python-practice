# %%
import os
cwd = os.getcwd()
print(f'Current working directory: {cwd}')
# Out:
# Current working directory: c:\Users\91814\python-practice-1\5-FileHandling

# %%
## create a new directory
new_dir = "package"
os.mkdir(new_dir)
print(f"Directory '{new_dir}' created.")
# Out:
# Directory 'package' created.

# %%
### Listing files and directories
items = os.listdir('.')
print(items)
# Out:
# ['5.1-fileOperation.ipynb', '5.2-filePath.ipynb', 'example.bin', 'example.txt', 'new_example.txt', 'package']

# %%
### Joining paths

dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(os.getcwd(),dir_name, file_name)
print(f"Full path: {full_path}")
# Out:
# Full path: c:\Users\91814\python-practice-1\5-FileHandling\folder\file.txt

# %%
path = 'example1.txt'
if os.path.isfile(path):
    print(f'The path{path} exists')
else:
    print(f'The path{path} does not exist')
# Out:
# The pathexample1.txt does not exist

# %%
## Getting the absolute path

relative_path = 'example.txt'
absolute_path = os.path.abspath(relative_path)
print(f'Absolute path: {absolute_path}')
# Out:
# Absolute path: c:\Users\91814\python-practice-1\5-FileHandling\example.txt

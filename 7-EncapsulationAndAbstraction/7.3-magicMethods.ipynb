# %% [markdown]
# Magic methods are also known as dunder methods(double underscore methods). They usually start and end with double underscores.
#
# They are predefined methods in Python that you can override to change the behaviour of your objects
# -init
# -str
# -reps
# -len
# -getitem
# -setitem

# %%
class Person():
    pass

person = Person()
dir(person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
print(person)

# %%
## Basic magic methods
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    def __str__(self):
        return f'{self.name} is {self.age} years old.'
    


person1 = Person('Harry', 28)
print(person1)
# Out:
# Harry is 28 years old.

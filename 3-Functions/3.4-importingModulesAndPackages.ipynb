# %% [markdown]
# ### Importing modules and packages

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
import numpy as np
np.array([1, 2, 3])
# Out:
# array([1, 2, 3])

# %%
from math import *
print(pi)
# Out:
# 3.141592653589793

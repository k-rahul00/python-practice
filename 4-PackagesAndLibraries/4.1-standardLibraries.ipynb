# %% [markdown]
# ## Standard Library in Python

# %%
import array
arr = array.array('i', [1, 2, 3, 4])

# %%
import math
print(math.pi)
print(math.sqrt(16))
print(math.factorial(8))
print(math.gcd(87, 16))
# Out:
# 3.141592653589793
# 4.0
# 40320
# 1

# %%
import random
print(random.randint(1, 100))
print(random.choice(['apple', 'banana', 'cherry']))
# Out:
# 93
# cherry

# %%
## File and directory access
import os
print(os.getcwd())
print(os.listdir())
print(os.path.isfile('requirements.txt'))
# Out:
# c:\Users\91814\python-practice-1\4-PackagesAndLibraries
# ['4.1-standardLibraries.ipynb']
# False

# %%
## High level operations on files
import shutil
shutil.copy('requirements.txt', 'requirements_copy.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 ## High level operations on files
#       2 import shutil
# ----> 3 shutil.copy('requirements.txt', 'requirements_copy.txt')
#
# File c:\Users\91814\python-practice-1\venv\Lib\shutil.py:489, in copy(src, dst, follow_symlinks)
#     487 if os.path.isdir(dst):
#     488     dst = os.path.join(dst, os.path.basename(src))
# --> 489 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     490 copymode(src, dst, follow_symlinks=follow_symlinks)
#     491 return dst
#
# File c:\Users\91814\python-practice-1\venv\Lib\shutil.py:313, in copyfile(src, dst, follow_symlinks)
#     311     os.symlink(os.readlink(src), dst)
#     312 else:
# --> 313     with open(src, 'rb') as fsrc:
#     314         try:
#     315             with open(dst, 'wb') as fdst:
#     316                 # macOS
#
# FileNotFoundError: [Errno 2] No such file or directory: 'requirements.txt'

# %%
## Data serialization
import json
data = {'name':'Frank', 'age' : 45}
jsonStr = json.dumps(data)
print(jsonStr)
print(type(jsonStr))

parsedData = json.loads(jsonStr)
print(parsedData)
print(type(parsedData))
# Out:
# {"name": "Frank", "age": 45}
# <class 'str'>
# {'name': 'Frank', 'age': 45}
# <class 'dict'>

# %%
## csv
import csv
with open('example.csv', mode = 'w', newline = '') as file:
    writer = csv.writer(file)
    writer.writerow(['Name', 'Age'])
    writer.writerow(['Alice', 30])

with open('example.csv', mode = 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Age']
# ['Alice', '30']

# %%
## dateTime 

from datetime import datetime, timedelta
now = datetime.now()
print(now)

yesterday = now - timedelta(days = 1)
print(yesterday)
# Out:
# 2026-04-02 13:32:51.063805
# 2026-04-01 13:32:51.063805

# %%
## time
import time 
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1775118220.1238236
# 1775118222.1247268

# %%
## Regex

import re
pattern = r'\d+'
text = 'There are 123 apples'
match = re.search(pattern, text)
print(match.group())
# Out:
# 123
